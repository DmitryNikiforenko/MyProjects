# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
from scipy.optimize import fsolve

# %%
x1 = []
x2 = []
y1 = []
y2 = []
R = 100
for i in range(1000):
    x1.append(-i)
    x2.append(i)
    y1.append(np.sqrt(R**2 - i**2))
    y2.append(-np.sqrt(R**2 - i**2)) 
plt.figure(figsize = (5, 5))
plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x2, y1)
plt.plot(x2, y2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/4085482140.py:9: RuntimeWarning: invalid value encountered in sqrt
#   y1.append(np.sqrt(R**2 - i**2))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/4085482140.py:10: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(R**2 - i**2))
# Text(0, 0.5, 'y')

# %%
x1 = []
x2 = []
y1 = []
y2 = []
a = 400
b = 10
for i in range(1000):
    x1.append(i)
    x2.append(-i)
    y1.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))  
plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x2, y2)
plt.plot(x2, y1)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/2666517810.py:10: RuntimeWarning: invalid value encountered in sqrt
#   y1.append(np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/2666517810.py:11: RuntimeWarning: invalid value encountered in sqrt
#   y2.append(-np.sqrt(b ** 2 - (b ** 2 * (i ** 2 / a ** 2))))
# Text(0, 0.5, 'y')

# %%
x1 = []
x2 = []
y1 = []
y2 = []
a = 100
b = 10
for i in range(1000):
    x1.append(i)
    x2.append(-i)
    y1.append(np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))
    y2.append(-np.sqrt(b ** 2 + (b ** 2 * (i ** 2 / a ** 2))))  
plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x2, y2)
plt.plot(x2, y1)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig = figure()
ax = Axes3D(fig)
x = np.arange(-5, 5, 0.5)
y = np.arange(-5, 5, 0.5)
x, y = np.meshgrid(x, y)
z1 = 2*x + 3*y + 20
z2 = 2*x + 3*y 
ax.plot_surface(x, y, z1)
ax.plot_surface(x, y, z2)
# Out:
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/126224386.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
fig = figure()
ax = Axes3D(fig)
x = np.arange(-500, 500, 0.5)
y = np.arange(-500, 500, 0.5)
x, y = np.meshgrid(x, y)
a = 120
b = 100
c = 80
z1 = np.sqrt(c**2 - (x**2 * c**2/a - y**2 * c**2/b))
z2 = -np.sqrt(c**2 - (x**2 * c**2/a - y**2 * c**2/b))
ax.plot_surface(x, y, z1)
ax.plot_surface(x, y, z2)
# Out:
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/414716359.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/414716359.py:9: RuntimeWarning: invalid value encountered in sqrt
#   z1 = np.sqrt(c**2 - (x**2 * c**2/a - y**2 * c**2/b))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/414716359.py:10: RuntimeWarning: invalid value encountered in sqrt
#   z2 = -np.sqrt(c**2 - (x**2 * c**2/a - y**2 * c**2/b))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/414716359.py:11: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax.plot_surface(x, y, z1)
# ...

# %%
fig = figure()
ax = Axes3D(fig)
x = np.arange(-100, 100, 1)
y = np.arange(-100, 100, 1)
x, y = np.meshgrid(x, y)
a = 10000
b = 10000
c = 10
z1 = np.sqrt(c**2 - (x**2 * c**2/a + y**2 * c**2/b))
z2 = -np.sqrt(c**2 - (x**2 * c**2/a + y**2 * c**2/b))
ax.plot_surface(x, y, z1)
ax.plot_surface(x, y, z2)
# Out:
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/1370790161.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/1370790161.py:9: RuntimeWarning: invalid value encountered in sqrt
#   z1 = np.sqrt(c**2 - (x**2 * c**2/a + y**2 * c**2/b))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/1370790161.py:10: RuntimeWarning: invalid value encountered in sqrt
#   z2 = -np.sqrt(c**2 - (x**2 * c**2/a + y**2 * c**2/b))
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/1370790161.py:11: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax.plot_surface(x, y, z1)
# ...

# %%
x = np.linspace(-2*np.pi, 3*np.pi, 200)
k1 = 0.5
k2 = 1
k3 = 2
a1 = 3
a2 = 7
a3 = 2
b1 = 2
b2 = 3
b3 = 6
plt.plot(x, k1*np.cos((x - a1) + b1))
plt.plot(x, k2*np.cos((x - a2) + b2))
plt.plot(x, k3*np.cos((x - a3) + b3))
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

# %%
x1 = []
x2 = []
y1 = []
y2 = []
R = 100
a1 = np.linspace(0, 2*np.pi, 100)
for a in a1:
    x1.append(R*np.cos(a))
    x2.append(-R*np.cos(a))
    y1.append(R*np.sin(a))
    y2.append(-R*np.sin(a)) 
plt.figure(figsize = (5, 5))
plt.plot(x1, y1)
plt.plot(x1, y2)
plt.plot(x2, y1)
plt.plot(x2, y2)
plt.xlabel('x')
plt.ylabel('y') 
plt.grid(True)

# %%
r = 5
a = 30
x = r*np.cos(a)
y = r*np.sin(a)
print(x, y)
# Out:
# 0.7712572494379202 -4.940158120464309

# %%
x = np.linspace(0, np.pi*2, 100)
y = [5]*len(x)
plt.polar(x, y)

# %%
a = np.linspace(2, 6, 2)
b = np.linspace(1, 4, 2)
plt.polar(a, b)

# %%
def equations(p):
    x, y = p
    return (x**2 - 1 - y, np.exp(x) + x * (1 - y) - 1)

x1, y1 =  fsolve(equations, (3, 7))
x2, y2 =  fsolve(equations, (-2, 1))
              
print (x1, y1)
print (x2, y2)

x = np.linspace(-2, 3, 200)
plt.plot(x, (np.exp(x)+ x - 1)/x)
plt.plot(x, x**2 - 1)
plt.grid(True)
plt.ylim(-1, 7)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# 2.6181455730854726 5.854686241867074
# -1.581835352893692 1.502203083670816
# Text(0, 0.5, 'y')

# %%
def eq(p):
    x, y = p
    return (x**2 - 1 - y, (- 1/x)+2 - y)

x1, y1 =  fsolve(eq, (3, 2.5))
x2, y2 =  fsolve(eq, (0.5, 0.5))
x3, y3 =  fsolve(eq, (-2, 1))
              
print (x1, y1)
print (x2, y2)
print (x3, y3)

x = np.linspace(-2, 3, 201)
plt.plot(x, (- 1/x)+2)
plt.plot(x, x**2 - 1)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1,7) 
plt.grid(True)
# Out:
# 1.532088886238745 1.3472963553343926
# 0.3472963553346955 -0.8793852415708359
# -1.8793852415717862 2.5320888862379842
# C:\Users\nikif\AppData\Local\Temp/ipykernel_7852/573086293.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x, (- 1/x)+2)
